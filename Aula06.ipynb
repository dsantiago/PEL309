# %%
import pandas as pd
from sklearn.datasets import load_diabetes

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = load_diabetes(as_frame=True)['frame']
df
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6  target
# ...

# %%
sex = df.sex.apply(lambda x: 'M' if x > 0 else 'F')
sex.value_counts().plot.pie(autopct='%1.1f%%');

# %% [markdown]
# ## Histograma das Colunas

# %%
fig, axes = plt.subplots(3, 3, figsize=(12, 8))
axes = axes.ravel()

i = 0
for col in df.columns:
    if col in ['sex', 'target']:
        continue

    axes[i].hist(df[col], bins=30, edgecolor='black', alpha=0.7)
    axes[i].set_title(col)
    axes[i].set_xlabel('Value')
    axes[i].set_ylabel('Frequency')
    i += 1


plt.tight_layout()
plt.show()

# %% [markdown]
# ## Boxplot das Colunas

# %%
fig, axes = plt.subplots(3, 3, figsize=(12, 8))
axes = axes.ravel()

i = 0
for col in df.columns:
    if col in ['sex', 'target']:
        continue

    axes[i].boxplot(df[col], vert=False)
    axes[i].set_title(col)
    axes[i].set_xlabel('Value')
    axes[i].set_ylabel('Frequency')
    i += 1


plt.tight_layout()
plt.show()

# %% [markdown]
# ## Heatmap de Correlação
#
# Mapa de calor da correlação entre os atributos, por padrão é usado a correlação de Pearson

# %%
sns.set(style="white")
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', vmin=-1, linewidths=0.5)
plt.title('Heatmap de Correlação - Dados de Gorjetas')
plt.show()
